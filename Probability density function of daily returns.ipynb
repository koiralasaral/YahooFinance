# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Download historical stock price data for S&P 500 index (^GSPC)
ticker = 'TKC'
data = yf.download(ticker, start='2020-01-01', end='2025-01-01')

# Step 2: Calculate daily returns
data['Weekly Returns'] = data['Close'].pct_change()

# Step 3: Remove NaN values
returns = data['Weekly Returns'].dropna()

# Step 4: Fit a normal distribution to the returns
mu, std = norm.fit(returns)

# Step 5: Plot the PDF
plt.hist(returns, bins=50, density=True, alpha=0.6, color='g', label='Histogram of Returns')

# Overlay the fitted PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, mu, std)
plt.plot(x, pdf, 'k', linewidth=2, label='Fitted PDF')

# Add labels and legend
plt.title(f"PDF of Daily Returns for {ticker}")
plt.xlabel("Weekly Returns")
plt.ylabel("Density")
plt.legend()

# Show the plot
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Download historical stock price data for S&P 500 index (^GSPC)
ticker = '^GSPC'
data = yf.download(ticker, start='2020-01-01', end='2025-01-01')

# Step 2: Calculate daily returns
data['Daily Returns'] = data['Close'].pct_change()

# Step 3: Remove NaN values
returns = data['Daily Returns'].dropna()

# Step 4: Fit a normal distribution to the returns
mu, std = norm.fit(returns)

# Step 5: Plot the PDF
plt.hist(returns, bins=50, density=True, alpha=0.6, color='g', label='Histogram of Returns')

# Overlay the fitted PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, mu, std)
plt.plot(x, pdf, 'k', linewidth=2, label='Fitted PDF')

# Add labels and legend
plt.title(f"PDF of Daily Returns for {ticker}")
plt.xlabel("Daily Returns")
plt.ylabel("Density")
plt.legend()

# Show the plot
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Download historical stock price data for S&P 500 index (^GSPC)
ticker = 'NVO'
data = yf.download(ticker, start='2020-01-01', end='2025-01-01')

# Step 2: Calculate daily returns
data['Daily Returns'] = data['Close'].pct_change()

# Step 3: Remove NaN values
returns = data['Daily Returns'].dropna()

# Step 4: Fit a normal distribution to the returns
mu, std = norm.fit(returns)

# Step 5: Plot the PDF
plt.hist(returns, bins=50, density=True, alpha=0.6, color='g', label='Histogram of Returns')

# Overlay the fitted PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, mu, std)
plt.plot(x, pdf, 'k', linewidth=2, label='Fitted PDF')

# Add labels and legend
plt.title(f"PDF of Daily Returns for {ticker}")
plt.xlabel("Daily Returns")
plt.ylabel("Density")
plt.legend()

# Show the plot
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Download historical stock price data for S&P 500 index (^GSPC)
ticker = 'GC=F'
data = yf.download(ticker, start='2020-01-01', end='2025-01-01')

# Step 2: Calculate daily returns
data['Daily Returns'] = data['Close'].pct_change()

# Step 3: Remove NaN values
returns = data['Daily Returns'].dropna()

# Step 4: Fit a normal distribution to the returns
mu, std = norm.fit(returns)

# Step 5: Plot the PDF
plt.hist(returns, bins=50, density=True, alpha=0.6, color='g', label='Histogram of Returns')

# Overlay the fitted PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, mu, std)
plt.plot(x, pdf, 'k', linewidth=2, label='Fitted PDF')

# Add labels and legend
plt.title(f"PDF of Daily Returns for {ticker}")
plt.xlabel("Daily Returns")
plt.ylabel("Density")
plt.legend()

# Show the plot
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Download historical stock price data for S&P 500 index (^GSPC)
ticker = 'F4S0.F'
data = yf.download(ticker, start='2020-01-01', end='2025-01-01')

# Step 2: Calculate daily returns
data['Daily Returns'] = data['Close'].pct_change()

# Step 3: Remove NaN values
returns = data['Daily Returns'].dropna()

# Step 4: Fit a normal distribution to the returns
mu, std = norm.fit(returns)

# Step 5: Plot the PDF
plt.hist(returns, bins=50, density=True, alpha=0.6, color='g', label='Histogram of Returns')

# Overlay the fitted PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, mu, std)
plt.plot(x, pdf, 'k', linewidth=2, label='Fitted PDF')

# Add labels and legend
plt.title(f"PDF of Daily Returns for {ticker}")
plt.xlabel("Daily Returns")
plt.ylabel("Density")
plt.legend()

# Show the plot
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
